# %% [markdown]
# <a href="https://colab.research.google.com/github/springboardmentor98352-maker/SafteyEye/blob/main/safety_eye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive"
# Out:
# '100842405-1 (1).pdf'
#  100842405-1.pdf
# 'archive (3).zip'
# 'Audio from ~Sanmaya~'
# 'Audio from ~Sanmaya~ (1)'
# 'Colab Notebooks'
#  Datasets
# 'DocScanner 29 Jan 2025 11-11 (1).pdf'
# 'DocScanner 29 Jan 2025 11-11.pdf'
# 'Document from ~Sanmaya~'
# 'Document from ~Sanmaya~ (1)'
# 'Document from ~Sanmaya~ (1).pdf'
# 'Document from ~Sanmaya~ (2)'
# 'Document from ~Sanmaya~ (3)'
# 'Document from ~Sanmaya~.pdf'
# 'IDEATHON-2025_Presentation_Format (1).pdf'
#  info.pdf
# 'Resume 2.pdf'
#  scr-2.pdf
# 'Untitled document.gdoc'

# %%
# !ls "/content/drive/MyDrive/OneDrive/Sanmaya - Personal"
# Out:
# ls: cannot access '/content/drive/MyDrive/OneDrive/Sanmaya - Personal': No such file or directory

# %%
# !ls "/content/drive/MyDrive"
# Out:
# '100842405-1 (1).pdf'
#  100842405-1.pdf
# 'archive (3).zip'
# 'Audio from ~Sanmaya~'
# 'Audio from ~Sanmaya~ (1)'
# 'Colab Notebooks'
#  Datasets
# 'DocScanner 29 Jan 2025 11-11 (1).pdf'
# 'DocScanner 29 Jan 2025 11-11.pdf'
# 'Document from ~Sanmaya~'
# 'Document from ~Sanmaya~ (1)'
# 'Document from ~Sanmaya~ (1).pdf'
# 'Document from ~Sanmaya~ (2)'
# 'Document from ~Sanmaya~ (3)'
# 'Document from ~Sanmaya~.pdf'
# 'IDEATHON-2025_Presentation_Format (1).pdf'
#  info.pdf
# 'Resume 2.pdf'
#  scr-2.pdf
# 'Untitled document.gdoc'

# %%
# !unzip "/content/drive/MyDrive/archive (3).zip" -d "/content/dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.0a21e9e91348b61c6c1483d6884d2135.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.3313bb2b19a7aa3a0af745abe858ec8e.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.3bbcfef23f20b2cf747256793dcfc615.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.6cee1b67a21808fad2318593379f9986.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.ddd7840e3d846cddfcc13d99f4a6999b.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-2_jpg.rf.4d46f38425296af74814d1f0506575b4.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-2_jpg.rf.58de1db8826e4221df63fd980b823844.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-2_jpg.rf.87e69eb0f5f24cbadcca3fbfe8ca029c.jpg
# ...

# %%
# !ls "/content/drive/MyDrive"
# Out:
# '100842405-1 (1).pdf'
#  100842405-1.pdf
# 'archive (3).zip'
# 'Audio from ~Sanmaya~'
# 'Audio from ~Sanmaya~ (1)'
# 'Colab Notebooks'
#  Datasets
# 'DocScanner 29 Jan 2025 11-11 (1).pdf'
# 'DocScanner 29 Jan 2025 11-11.pdf'
# 'Document from ~Sanmaya~'
# 'Document from ~Sanmaya~ (1)'
# 'Document from ~Sanmaya~ (1).pdf'
# 'Document from ~Sanmaya~ (2)'
# 'Document from ~Sanmaya~ (3)'
# 'Document from ~Sanmaya~.pdf'
# 'IDEATHON-2025_Presentation_Format (1).pdf'
#  info.pdf
# 'Resume 2.pdf'
#  scr-2.pdf
# 'Untitled document.gdoc'

# %%
# !rm -rf /content/dataset
# !mkdir /content/dataset

# %%
# !unzip "/content/drive/MyDrive/archive (3).zip" -d "/content/dataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.0a21e9e91348b61c6c1483d6884d2135.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.3313bb2b19a7aa3a0af745abe858ec8e.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.3bbcfef23f20b2cf747256793dcfc615.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.6cee1b67a21808fad2318593379f9986.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-25_jpg.rf.ddd7840e3d846cddfcc13d99f4a6999b.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-2_jpg.rf.4d46f38425296af74814d1f0506575b4.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-2_jpg.rf.58de1db8826e4221df63fd980b823844.jpg
#   inflating: /content/dataset/css-data/train/images/IMG_3100_mp4-2_jpg.rf.87e69eb0f5f24cbadcca3fbfe8ca029c.jpg
# ...

# %%
# !find /content/dataset -maxdepth 2 -type d
# Out:
# /content/dataset
# /content/dataset/results_yolov8n_100e
# /content/dataset/results_yolov8n_100e/kaggle
# /content/dataset/css-data
# /content/dataset/css-data/valid
# /content/dataset/css-data/train
# /content/dataset/css-data/test
# /content/dataset/source_files
# /content/dataset/source_files/source_files

# %%
# %%writefile data.yaml
# train: /content/dataset/css-data/train
# val: /content/dataset/css-data/valid
#
# nc: 5
# names: ["Helmet", "Head", "Person", "Safety Vest", "No Helmet"]
# Out:
# Writing data.yaml

# %%
# !yolo detect train model=yolov8n.pt data=data.yaml epochs=50 imgsz=640
# Out:
# /bin/bash: line 1: yolo: command not found

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.4 MB/s eta 0:00:00
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.6/107.7 GB disk)

# %%
# !yolo detect train model=yolov8n.pt data=data.yaml epochs=50 imgsz=640
# Out:
# ...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# !ls runs/detect/train
# Out:
# args.yaml			 confusion_matrix.png  train_batch40.jpg
# BoxF1_curve.png			 results.csv	       train_batch41.jpg
# BoxP_curve.png			 results.png	       train_batch42.jpg
# BoxPR_curve.png			 train_batch0.jpg      val_batch0_labels.jpg
# BoxR_curve.png			 train_batch1.jpg      val_batch0_pred.jpg
# confusion_matrix_normalized.png  train_batch2.jpg      weights

# %%
# !ls runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt \
    source=/content/dataset/css-data/test/images \
    save=True
# Out:
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (Intel Xeon CPU @ 2.20GHz)
# Model summary (fused): 72 layers, 3,006,623 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/82 /content/dataset/css-data/test/images/-4405-_png_jpg.rf.82b5c10b2acd1cfaa24259ada8e599fe.jpg: 640x640 (no detections), 357.2ms
# image 2/82 /content/dataset/css-data/test/images/000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg: 640x640 (no detections), 352.0ms
# image 3/82 /content/dataset/css-data/test/images/002551_jpg.rf.ce4b9f934161faa72c80dc6898d37b2d.jpg: 640x640 (no detections), 274.8ms
# image 4/82 /content/dataset/css-data/test/images/003357_jpg.rf.9867f91e88089bb68dc95947d5116d14.jpg: 640x640 (no detections), 302.6ms
# image 5/82 /content/dataset/css-data/test/images/004063_jpg.rf.1b7cdc4035bcb24ef69b8798b444053e.jpg: 640x640 (no detections), 292.7ms
# image 6/82 /content/dataset/css-data/test/images/004763_jpg.rf.46484e6ca73caeaa9de45822cf1085a9.jpg: 640x640 (no detections), 281.5ms
# ...

# %%
# !ls runs/detect/predict
# Out:
# 000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg
# 002551_jpg.rf.ce4b9f934161faa72c80dc6898d37b2d.jpg
# 003357_jpg.rf.9867f91e88089bb68dc95947d5116d14.jpg
# 004063_jpg.rf.1b7cdc4035bcb24ef69b8798b444053e.jpg
# 004763_jpg.rf.46484e6ca73caeaa9de45822cf1085a9.jpg
# 006463_jpg.rf.02f19082420ecc5537b9d59abbe6050c.jpg
# 006672_jpg.rf.87d5978c486feb53177408cf00a0d87f.jpg
# 0_jpg.rf.2ff49f74309118f169e07aa12564df87.jpg
# 2008_008320_jpg.rf.bd34011d46f82f9410d95f00e560b8ea.jpg
# 2008_008519_jpg.rf.1798c8eed7de04399a0e7e297b4b4c9e.jpg
# 2009_000059_jpg.rf.50e8398a37eb33f33fd9f662feeea083.jpg
# 2009_000496_jpg.rf.9a2d210fe0f5ea4b572aeb07e41ecbae.jpg
# 3e7e40981ddd4cdb055c7ffe4c2af5d8_jpg.rf.bac50dc18195e9aeb6f3a21782a3efcb.jpg
# -4405-_png_jpg.rf.82b5c10b2acd1cfaa24259ada8e599fe.jpg
# 777_jpg.rf.92dc6945342410ced7ac93f3dfbff0c5.jpg
# autox3_mp4-187_jpg.rf.8340e2bd65afade3fb0d3194eadc5796.jpg
# autox3_mp4-277_jpg.rf.a5ed8fd043fe7e1d8682768880b6d4db.jpg
# ...

# %%
from IPython.display import Image
Image(filename='runs/detect/predict/000005_jpg.rf.96e9379ccae638140c4a90fc4b700a2b.jpg')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
